# %% [markdown]
# <center>
# <font face="Libertine">
# <font size="6"> <b> High Performance Web-Client <br/><br/> Programming with SPOC <br/><br/> and <pre>Js_of_OCaml</pre> </b> </font> <br/><br/>
#
# <font size="5"> OCaml 2014 </font> <br/> </font>
#
# <font size="4"> <u>Mathias Bourgoin</u> & Emmanuel Chailloux </font>
# <br/>
# September 5, 2014
# <br/>
#
# <br/>
# <br/>
#
# <font/>
# </center>
#
#
# <img height="80" width="70" src="../pres_resources/logo-lip6.jpg" />
# <img align="right" height="80" width="180" src="../pres_resources/upmc.jpg" />

# %% [markdown]
# <font face="Libertine">
# ## GPGPU Programming
# ## GPGPU Programming with OCaml
# ## WebSPOC
# ## Demo!
# ## Conclusion
# <font/>

# %% [markdown]
# # Parallel OCaml?
#
# ## On Multicore CPU
#
# ** ParMap**
#
# ** OC4MC (OCaml 4 Multicore) **
#
# ** SPOC (Stream Processing OCaml) ** (with OpenCL)
#
# ** JOCaml **
#
# ** Async Parallel **
#
# ** Multicore OCaml **
#
# ** Probably more! **

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> GPGPU Programming </b></font>
#
# <div id="container" style="width:1000px">
#
#
#
# <div id="menu" style="float:left;">
# <img height="80" width="200" src="../pres_resources/Tesla_C2070.jpg" />
# <br>
# <img height="80" width="200" src="../pres_resources/ati_v9800.jpg" />
# </div>
#
# <div id="content" style=" float:left;">
# <ul>
# <li><b>Two main frameworks:</b>
#     <ul>
#     <li> Cuda (Nvidia)</li>
#     <li> OpenCL (standard) </li>
#     </ul>
# </li>
# <li><b>Different languages:</b>
#     <ul>
#     <li><i>To write kernels:</i>
#     <ul>
#         <li>Assembly (ptx, il,. . . )</li>
#         <li>subsets of C/C++</li>
#     </ul>
#     </li>
#     <li><i>To manage kernels:</i>
#     <ul>
#         <li>C/C++/Objective-C</li>
#         <li>Fortran</li>
#         <li>Python</li>
#         <li>Scala</li>
#         <li>Java</li>
#         <li>Scilab</li>
#         <li>F#</li>
#         <li>Rust</li>
#     </ul>
#     </li>
# </li>
# </ul></div>
# </div>
#
# </font>

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> GPGPU Programming with OCaml</b></font>
#
# <img height="100" width="450" src="../pres_resources/figure_coul.jpg"/>
# </font>

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> WebSpoc</b></font>
#
# <center>
# <img height="10000" width="320" src="../pres_resources/compilation.jpg" />
#
# </center>
# </font>

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b>Demo</b></font>
#
# </font>

# %%
open Spoc

(* Sarek kernel *)
(* reads the RGB values of each pixel stored in an
   RGBA int vector and produces a gray value :
   Gray =  0.21×R+0.71×G+0.07×B *)
let gpu_gray = kern v ->
    let open Std in
    let tid = global_thread_id in 
        if tid <= (512*512) then (
    let i = (tid*4) in
    let gray = int_of_float
            ((0.21 *. (float (v.[<i>]))) +. 
             (0.71 *. (float (v.[<i+1>]))) +. 
             (0.07 *. (float (v.[<i+2>]))) ) in
    v.[<i>] <- gray; 
    v.[<i+1>] <- gray; 
    v.[<i+2>] <- gray)
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val gpu_gray :
#   &lt; args_to_list : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array;
#     compile : ?debug:bool -&gt; Spoc.Devices.device -&gt; unit;
#     compile_and_run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                       Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#                       ?debug:bool -&gt; int -&gt; Spoc.Devices.device -&gt; unit;
#     exec : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#            Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#            int -&gt; Spoc.Devices.device -&gt; Spoc.Kernel.kernel -&gt; unit;
#     get_binaries : unit -&gt;
#                    (Spoc.Devices.device, Spoc.Kernel.kernel) Hashtbl.t;
#     get_cuda_sources : unit -&gt; string list;
#     get_opencl_sources : unit -&gt; string list;
#     list_to_args : (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Vector.vector;
#     reload_sources : unit -&gt; unit; reset_binaries : unit -&gt; unit;
#     run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#           Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#           int -&gt; Spoc.Devices.device -&gt; unit;
#     set_cuda_sources : string -&gt; unit; set_opencl_sources : string -&gt; unit &gt; *
#   ((int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt; unit, unit, unit)
#   Kirc.kirc_kernel =
#   (&lt;obj&gt;,
#    {Kirc.ml_kern = &lt;fun&gt;; body = &lt;abstr&gt;;
#     ret_val = (&lt;abstr&gt;, Spoc.Vector.Unit ((), ()));
#     extensions = [|Kirc.ExFloat32|]})
# </pre>

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> Manage our webpage with OCaml</b></font>
# *
#
# </font>
# <img id="orig_img" src="../tutos/lena.png" style="display: none;"/></img>

# %%
let error f = Printf.ksprintf 
(fun s -> Firebug.console##error (Js.string s); 
failwith s) f

(*get the image hidden in the previous slide*)
let image = 
 Js.Opt.get(
  Js.Opt.bind 
   (Dom_html.document##getElementById(Js.string "orig_img"))
   Dom_html.CoerceTo.img)
  (fun () -> error 
            "can't find img element orig_img")
            
(*access next slide*)
let original_canvas =   
 Js.Opt.get(
  Js.Opt.bind 
   (Dom_html.document##getElementById
                       (Js.string "canvas_original"))
   Dom_html.CoerceTo.canvas)
  (fun () -> error 
            "can't find canvas element original")
            
(*show image*)
let c2D_orig = original_canvas##getContext 
                (Dom_html._2d_);;
                
let () = 
    let e = Js.Opt.get
    (Js.Opt.bind 
    (Dom_html.document##getElementById(Js.string "next_slide"))
        Dom_html.CoerceTo.p)
     (fun () -> error "can't find next_slide")
    in
    e##innerHTML<- Js.string "Original Picture";
    c2D_orig##drawImage (image, 0., 0.);;
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val error : ('a, unit, string, 'b) format4 -&gt; 'a = &lt;fun&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val image : Dom_html.imageElement Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val original_canvas : Dom_html.canvasElement Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val c2D_orig : Dom_html.canvasRenderingContext2D Js.t = &lt;abstr&gt;
# </pre>

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> <p id="next_slide"> An empty slide<p/></b></font>
#
# </font><canvas  id="canvas_original" width="512" height="512">
# </canvas>

# %%
let original_imageData = c2D_orig##getImageData 
                            (0., 0., 512., 512.)
  
let original_data = original_imageData##data

let final_canvas = 
 Js.Opt.get(
  Js.Opt.bind (
   Dom_html.document##getElementById(Js.string "canvas_final"))
  Dom_html.CoerceTo.canvas)
 (fun () -> error "can't find canvas element final")

let image2 : Dom_html.imageElement Js.t = 
 Dom_html.createImg Dom_html.document

let c2D_final = final_canvas##getContext 
                                (Dom_html._2d_)
    
let final_imageData = c2D_final##getImageData 
                        (0., 0., 512., 512.)
let final_data = final_imageData##data

let imgData_to_vector data = 
    let vect = Vector.create Vector.int32 (512*512*4) 
    in
    for i = 0 to Vector.length vect - 1 do
    vect.[<i>] <- Int32.of_int 
                    (Dom_html.pixel_get data i);
  done;
  vect

let vector_to_imgData vect data = 
    for i = 0 to Vector.length vect - 1 do
    Dom_html.pixel_set data i (Int32.to_int vect.[<i>])
  done
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val original_imageData : Dom_html.imageData Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val original_data : Dom_html.canvasPixelArray Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val final_canvas : Dom_html.canvasElement Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val image2 : Dom_html.imageElement Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val c2D_final : Dom_html.canvasRenderingContext2D Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val final_imageData : Dom_html.imageData Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val final_data : Dom_html.canvasPixelArray Js.t = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val imgData_to_vector :
#   Dom_html.canvasPixelArray Js.t -&gt;
#   (int32, Bigarray.int32_elt) Spoc.Vector.vector = &lt;fun&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val vector_to_imgData :
#   (int32, 'a) Spoc.Vector.vector -&gt; Dom_html.canvasPixelArray Js.t -&gt; unit =
#   &lt;fun&gt;
# </pre>

# %%
(* make sure we're using a GPU *)
let devs = Devices.init ~only:Devices.OpenCL () 
(*Keep GPUs only*)
        |>  Array.to_list |>
        List.filter 
        (fun d -> 
            match d.Devices.specific_info with 
            | Devices.OpenCLInfo clI -> 
              (match clI.Devices.device_type with
               | Devices.CL_DEVICE_TYPE_CPU -> false
               | _ -> true)
            | _ -> true) |> Array.of_list
            
let dev =  devs.(0)

(* one thread per pixel *)

(* Nb threads per block *)
(* depends on your specific device *) 
(* 256 should be compatible with most GPUs *)
let threadsPerBlock = 
    match dev.Devices.specific_info with
    | Devices.OpenCLInfo clI -> 
      (match clI.Devices.device_type with
       | Devices.CL_DEVICE_TYPE_CPU -> 1
       | _  ->   256)
    | Devices.CudaInfo cuI -> failwith "WebCuda doesn't exist" 
  
let blocksPerGrid =
    ((512*512) + threadsPerBlock-1) / threadsPerBlock

(* 1D block *)
let block = {Spoc.Kernel.blockX = threadsPerBlock;
      Spoc.Kernel.blockY = 1; Spoc.Kernel.blockZ = 1}

(* 1D Grid *)
let grid = {Spoc.Kernel.gridX = blocksPerGrid;
        Spoc.Kernel.gridY = 1; Spoc.Kernel.gridZ = 1}
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val devs : Spoc.Devices.device array =
#   [|{Spoc.Devices.general_info =
#       {Spoc.Devices.name = &quot;GeForce 9400M&quot;; totalGlobalMem = 268435456;
#        localMemSize = 16384; clockRate = 1100; totalConstMem = 65536;
#        multiProcessorCount = 2; eccEnabled = false; id = 1; ctx = &lt;abstr&gt;};
#      specific_info =
#       Spoc.Devices.OpenCLInfo
#        {Spoc.Devices.platform_info =
#          {Spoc.Devices.platform_profile = &quot;WEBCL_PROFILE&quot;;
#           platform_version = &quot;WebCL 1.0&quot;; platform_name = &quot;Apple&quot;;
#           platform_vendor = &quot;Apple&quot;;
#           platform_extensions =
#            &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event&quot;;
#           num_devices = 3};
#         device_type = Spoc.Devices.CL_DEVICE_TYPE_GPU;
#         profile = &quot;WEBCL_PROFILE&quot;; version = &quot;WebCL 1.0&quot;; vendor = &quot;NVIDIA&quot;;
#         extensions =
#          &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_byte_addressable_store cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics &quot;;
#         vendor_id = 16918016; max_work_item_dimensions = 3;
#         address_bits = 32; max_mem_alloc_size = 134217728;
#         image_support = true; max_read_image_args = 128;
#         max_write_image_args = 8; max_samplers = 16;
#         mem_base_addr_align = 1024; min_data_type_align_size = 0;
#         global_mem_cacheline_size = 0; global_mem_cache_size = 0;
#         max_constant_args = 9; endian_little = true; available = true;
#         compiler_available = true; single_fp_config = &lt;unknown constructor&gt;;
#         global_mem_cache_type = Spoc.Devices.CL_READ_WRITE_CACHE;
#         queue_properties = &lt;unknown constructor&gt;;
#         local_mem_type = Spoc.Devices.CL_GLOBAL;
#         double_fp_config = Spoc.Devices.CL_FP_DENORM;
#         max_constant_buffer_size = 65536;
#         execution_capabilities = Spoc.Devices.CL_EXEC_NATIVE_KERNEL;
#         half_fp_config = Spoc.Devices.CL_FP_DENORM;
#         max_work_group_size = 512; image2D_max_height = 4096;
#         image2D_max_width = 4096; image3D_max_depth = 0;
#         image3D_max_height = 0; image3D_max_width = 0;
#         max_parameter_size = 4352;
#         max_work_item_size = {Spoc.Devices.x = 512; y = 512; z = 64};
#         prefered_vector_width_char = 1; prefered_vector_width_short = 1;
#         prefered_vector_width_int = 1; prefered_vector_width_long = 1;
#         prefered_vector_width_float = 1; prefered_vector_width_double = 0;
#         profiling_timer_resolution = 1000;
#         driver_version = &quot;8.24.15 310.90.9.05f01&quot;; device_id = &lt;abstr&gt;};
#      gc_info = &lt;abstr&gt;; events = &lt;abstr&gt;};
#     {Spoc.Devices.general_info =
#       {Spoc.Devices.name = &quot;GeForce 9600M GT&quot;; totalGlobalMem = 268435456;
#        localMemSize = 16384; clockRate = 1250; totalConstMem = 65536;
#        multiProcessorCount = 4; eccEnabled = false; id = 2; ctx = &lt;abstr&gt;};
#      specific_info =
#       Spoc.Devices.OpenCLInfo
#        {Spoc.Devices.platform_info =
#          {Spoc.Devices.platform_profile = &quot;WEBCL_PROFILE&quot;;
#           platform_version = &quot;WebCL 1.0&quot;; platform_name = &quot;Apple&quot;;
#           platform_vendor = &quot;Apple&quot;;
#           platform_extensions =
#            &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event&quot;;
#           num_devices = 3};
#         device_type = Spoc.Devices.CL_DEVICE_TYPE_GPU;
#         profile = &quot;WEBCL_PROFILE&quot;; version = &quot;WebCL 1.0&quot;; vendor = &quot;NVIDIA&quot;;
#         extensions =
#          &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_byte_addressable_store cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics &quot;;
#         vendor_id = 33695232; max_work_item_dimensions = 3;
#         address_bits = 32; max_mem_alloc_size = 134217728;
#         image_support = true; max_read_image_args = 128;
#         max_write_image_args = 8; max_samplers = 16;
#         mem_base_addr_align = 1024; min_data_type_align_size = 0;
#         global_mem_cacheline_size = 0; global_mem_cache_size = 0;
#         max_constant_args = 9; endian_little = true; available = true;
#         compiler_available = true; single_fp_config = &lt;unknown constructor&gt;;
#         global_mem_cache_type = Spoc.Devices.CL_READ_WRITE_CACHE;
#         queue_properties = &lt;unknown constructor&gt;;
#         local_mem_type = Spoc.Devices.CL_GLOBAL;
#         double_fp_config = Spoc.Devices.CL_FP_DENORM;
#         max_constant_buffer_size = 65536;
#         execution_capabilities = Spoc.Devices.CL_EXEC_NATIVE_KERNEL;
#         half_fp_config = Spoc.Devices.CL_FP_DENORM;
#         max_work_group_size = 512; image2D_max_height = 4096;
#         image2D_max_width = 4096; image3D_max_depth = 0;
#         image3D_max_height = 0; image3D_max_width = 0;
#         max_parameter_size = 4352;
#         max_work_item_size = {Spoc.Devices.x = 512; y = 512; z = 64};
#         prefered_vector_width_char = 1; prefered_vector_width_short = 1;
#         prefered_vector_width_int = 1; prefered_vector_width_long = 1;
#         prefered_vector_width_float = 1; prefered_vector_width_double = 0;
#         profiling_timer_resolution = 1000;
#         driver_version = &quot;8.24.15 310.90.9.05f01&quot;; device_id = &lt;abstr&gt;};
#      gc_info = &lt;abstr&gt;; events = &lt;abstr&gt;}|]
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val dev : Spoc.Devices.device =
#   {Spoc.Devices.general_info =
#     {Spoc.Devices.name = &quot;GeForce 9400M&quot;; totalGlobalMem = 268435456;
#      localMemSize = 16384; clockRate = 1100; totalConstMem = 65536;
#      multiProcessorCount = 2; eccEnabled = false; id = 1; ctx = &lt;abstr&gt;};
#    specific_info =
#     Spoc.Devices.OpenCLInfo
#      {Spoc.Devices.platform_info =
#        {Spoc.Devices.platform_profile = &quot;WEBCL_PROFILE&quot;;
#         platform_version = &quot;WebCL 1.0&quot;; platform_name = &quot;Apple&quot;;
#         platform_vendor = &quot;Apple&quot;;
#         platform_extensions =
#          &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event&quot;;
#         num_devices = 3};
#       device_type = Spoc.Devices.CL_DEVICE_TYPE_GPU;
#       profile = &quot;WEBCL_PROFILE&quot;; version = &quot;WebCL 1.0&quot;; vendor = &quot;NVIDIA&quot;;
#       extensions =
#        &quot;cl_APPLE_SetMemObjectDestructor cl_APPLE_ContextLoggingFunctions cl_APPLE_clut cl_APPLE_query_kernel_names cl_APPLE_gl_sharing cl_khr_gl_event cl_khr_byte_addressable_store cl_khr_global_int32_base_atomics cl_khr_global_int32_extended_atomics &quot;;
#       vendor_id = 16918016; max_work_item_dimensions = 3; address_bits = 32;
#       max_mem_alloc_size = 134217728; image_support = true;
#       max_read_image_args = 128; max_write_image_args = 8; max_samplers = 16;
#       mem_base_addr_align = 1024; min_data_type_align_size = 0;
#       global_mem_cacheline_size = 0; global_mem_cache_size = 0;
#       max_constant_args = 9; endian_little = true; available = true;
#       compiler_available = true; single_fp_config = &lt;unknown constructor&gt;;
#       global_mem_cache_type = Spoc.Devices.CL_READ_WRITE_CACHE;
#       queue_properties = &lt;unknown constructor&gt;;
#       local_mem_type = Spoc.Devices.CL_GLOBAL;
#       double_fp_config = Spoc.Devices.CL_FP_DENORM;
#       max_constant_buffer_size = 65536;
#       execution_capabilities = Spoc.Devices.CL_EXEC_NATIVE_KERNEL;
#       half_fp_config = Spoc.Devices.CL_FP_DENORM; max_work_group_size = 512;
#       image2D_max_height = 4096; image2D_max_width = 4096;
#       image3D_max_depth = 0; image3D_max_height = 0; image3D_max_width = 0;
#       max_parameter_size = 4352;
#       max_work_item_size = {Spoc.Devices.x = 512; y = 512; z = 64};
#       prefered_vector_width_char = 1; prefered_vector_width_short = 1;
#       prefered_vector_width_int = 1; prefered_vector_width_long = 1;
#       prefered_vector_width_float = 1; prefered_vector_width_double = 0;
#       profiling_timer_resolution = 1000;
#       driver_version = &quot;8.24.15 310.90.9.05f01&quot;; device_id = &lt;abstr&gt;};
#    gc_info = &lt;abstr&gt;; events = &lt;abstr&gt;}
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val threadsPerBlock : int = 256
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val blocksPerGrid : int = 1024
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val block : Spoc.Kernel.block =
#   {Spoc.Kernel.blockX = 256; blockY = 1; blockZ = 1}
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val grid : Spoc.Kernel.grid =
#   {Spoc.Kernel.gridX = 1024; gridY = 1; gridZ = 1}
# </pre>

# %%
let vect = imgData_to_vector original_data

let run filter =
    ignore(Kirc.gen ~only:Devices.OpenCL filter);
    Kirc.run filter vect (block,grid) 0 dev;
    vector_to_imgData vect final_data;
    c2D_final##putImageData (final_imageData, 0., 0.);
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val vect : (int32, Bigarray.int32_elt) Spoc.Vector.vector = &lt;abstr&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val run :
#   ((int32, Bigarray.int32_elt) Spoc.Vector.vector, 'a, 'b, 'c, 'd)
#   Kirc.sarek_kernel -&gt; unit = &lt;fun&gt;
# </pre>

# %%
let () =
    run gpu_gray

# %% [markdown]
# <font face="Libertine"><font size="5"> <b>
# Hopefully, this slide contains the resulting picture</b></font></font>
#
# <br/>
# <canvas id="canvas_final" width="512" height="512">
# </canvas>

# %%
let demo_filter = kern v ->
    let open Std in
    let tid = global_thread_id in 
        if tid <= (512*512) then (
    let i = (tid*4) in
    let res = int_of_float
            ((0.21 *. (float (v.[<i>]))) +. 
             (0.71 *. (float (v.[<i+1>]))) +. 
             (0.07 *. (float (v.[<i+2>]))) ) in
    v.[<i>] <- res; 
    v.[<i+1>] <- res; 
    v.[<i+2>] <- res)
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val demo_filter :
#   &lt; args_to_list : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array;
#     compile : ?debug:bool -&gt; Spoc.Devices.device -&gt; unit;
#     compile_and_run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                       Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#                       ?debug:bool -&gt; int -&gt; Spoc.Devices.device -&gt; unit;
#     exec : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#            Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#            int -&gt; Spoc.Devices.device -&gt; Spoc.Kernel.kernel -&gt; unit;
#     get_binaries : unit -&gt;
#                    (Spoc.Devices.device, Spoc.Kernel.kernel) Hashtbl.t;
#     get_cuda_sources : unit -&gt; string list;
#     get_opencl_sources : unit -&gt; string list;
#     list_to_args : (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Vector.vector;
#     reload_sources : unit -&gt; unit; reset_binaries : unit -&gt; unit;
#     run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#           Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#           int -&gt; Spoc.Devices.device -&gt; unit;
#     set_cuda_sources : string -&gt; unit; set_opencl_sources : string -&gt; unit &gt; *
#   ((int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt; unit, unit, unit)
#   Kirc.kirc_kernel =
#   (&lt;obj&gt;,
#    {Kirc.ml_kern = &lt;fun&gt;; body = &lt;abstr&gt;;
#     ret_val = (&lt;abstr&gt;, Spoc.Vector.Unit ((), ()));
#     extensions = [|Kirc.ExFloat32|]})
# </pre>

# %%
let () =
    run demo_filter

# %% [markdown]
# <font face="Libertine">
# <font size="5"> <b> Conclusion </b></font>
#
# <ul>
# <li><b>WebSPOC helps develop :</b>
#     <ul>
#     <li> Complex web-applications with intensive computations</li>
#     <li> Multi-media web-applications with OCaml </li>
#     </ul>
# </li>
#
# <li><b>Perfect tool for :</b>
#     <ul>
#     <li> Demos/Tutorials?</li>
#     <li> GPGPU/HPC courses </li>
#     </ul>
# </li>
# </ul>
# <br/>
# <ul>
# <li><b>Future work :</b>
#     <ul>
#     <li> Add a JavaScript memory manager dedicated to SPOC vectors</li>
#     <li> Add bindings with WebGL </li>
#     </ul>
# </li>
# </ul>
#
# </font>

# %% [markdown]
# # Questions?
#
# **This demo is online : http://mathiasbourgoin.github.io/SPOC/tutos/OCaml2014.html **
#
# *Built using [IOCamlJS](http://github.com/andrewray/iocamljs), SPOC, Sarek and [Js_of_ocaml](http://github.com/ocsigen/js_of_ocaml)*
#
# *Runs in [Mozilla Firefox](http://www.mozilla.org/firefox/) with [Nokia Research WebCL plugin](http://webcl.nokiaresearch.com/)*
#
# SPOC and Sarek are available in OPAM :
#
#    + opam install spoc
#    + opam install sarek
