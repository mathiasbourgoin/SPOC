# %% [markdown]
# # SPOC and Sarek Mandelbrot sample

# %%
open Spoc;;
open Kirc;;

# %%
let width = ref 512;;
let height = ref 512;;
let max_iter  = ref 50;;

# %%
let mandelbrot = kern img -> 
  let open Std in
  let y = thread_idx_y + (block_idx_y * block_dim_y) in
  let x = thread_idx_x + (block_idx_x * block_dim_x) in
  if (y < !height) && (x < !width) then
     begin  
       let x0 = x  in
       let y0 = y  in
       let mutable cpt = 0 in 
       let mutable x1 = 0. in
       let mutable y1 = 0. in
       let mutable x2 = 0. in
       let mutable y2 = 0. in
       let a = 4. *. ((float x0) /. (float !width))   -. 2. in
       let b = 4. *. ((float y0) /. (float !height)) -. 2. in

       let mutable norm = x1 *. x1 +. y1 *. y1
       in
       while ((cpt < !max_iter) && (norm <=. 4.)) do
         cpt := (cpt + 1);
         x2 := (x1 *. x1) -. (y1 *. y1) +. a;
         y2 :=  (2. *. x1 *. y1 ) +. b;
         x1 := x2;
         y1 := y2;
         norm := (x1 *. x1 ) +. ( y1 *. y1);
       done;
       img.[<y * !width + x>] <- cpt
     end
;;
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val width : int ref = {contents = 512}
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val height : int ref = {contents = 512}
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val max_iter : int ref = {contents = 50}
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val mandelbrot :
#   &lt; args_to_list : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array;
#     compile : ?debug:bool -&gt; Spoc.Devices.device -&gt; unit;
#     compile_and_run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#                       Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#                       ?debug:bool -&gt; int -&gt; Spoc.Devices.device -&gt; unit;
#     exec : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#            Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#            int -&gt; Spoc.Devices.device -&gt; Spoc.Kernel.kernel -&gt; unit;
#     get_binaries : unit -&gt;
#                    (Spoc.Devices.device, Spoc.Kernel.kernel) Hashtbl.t;
#     get_cuda_sources : unit -&gt; string list;
#     get_opencl_sources : unit -&gt; string list;
#     list_to_args : (int32, Bigarray.int32_elt) Spoc.Kernel.kernelArgs array -&gt;
#                    (int32, Bigarray.int32_elt) Spoc.Vector.vector;
#     reload_sources : unit -&gt; unit; reset_binaries : unit -&gt; unit;
#     run : (int32, Bigarray.int32_elt) Spoc.Vector.vector -&gt;
#           Spoc.Kernel.block * Spoc.Kernel.grid -&gt;
#           int -&gt; Spoc.Devices.device -&gt; unit;
#     set_cuda_sources : string -&gt; unit; set_opencl_sources : string -&gt; unit &gt; *
#   ((int, Bigarray.int_elt) Spoc.Vector.vector -&gt; unit, int32,
#    Bigarray.int32_elt)
#   Kirc.kirc_kernel =
#   (&lt;obj&gt;,
#    {ml_kern = &lt;fun&gt;; body = &lt;abstr&gt;;
#     ret_val = (&lt;abstr&gt;, Spoc.Vector.Int32 &lt;abstr&gt;);
#     extensions = [|ExFloat32|]})
# </pre>

# %%
open Dom_html

let color n = 
  if n =  !max_iter then
    (196, 200, 200)
  else 
    let f n = 
      let i = float n in 
      int_of_float (255. *. (0.5 +. 0.5 *. sin(i *. 0.1))) in
    ((f (n + 32)),  (f(n + 16)),  (f n))


let compute devid devs data imageData c= 
  let dev = devs.(devid) in
  Printf.printf "Will use device : %s!"
    (dev).Spoc.Devices.general_info.Spoc.Devices.name;
  let gpu_vect = Spoc.Vector.create Vector.int32 (!width * !height)
  in
  Random.self_init ();

  let threadsPerBlock = match dev.Devices.specific_info with
    | Devices.OpenCLInfo clI -> 
      (match clI.Devices.device_type with
      | Devices.CL_DEVICE_TYPE_CPU -> 1
      | _  ->   16)
    | _  -> 16  in
  let blocksPerGridx =
    (!width + (threadsPerBlock) -1) / (threadsPerBlock) in
  let blocksPerGridy =
    (!height + (threadsPerBlock) -1) / (threadsPerBlock) in
  let block = {Spoc.Kernel.blockX = threadsPerBlock;
         Spoc.Kernel.blockY = threadsPerBlock;
            Spoc.Kernel.blockZ = 1}
  and grid= {Spoc.Kernel.gridX = blocksPerGridx;
       Spoc.Kernel.gridY = blocksPerGridy;
            Spoc.Kernel.gridZ = 1} in

     Kirc.run mandelbrot (gpu_vect) (block,grid) 0 dev;
      for i = 0 to Vector.length gpu_vect - 1 do
        let t = Int32.to_int gpu_vect.[<i>] in 
        let r,g,b = (color t) in 
        pixel_set data (i*4) r; 
        pixel_set data (i*4+1) g; 
        pixel_set data (i*4+2) b; 
        pixel_set data (i*4+3) 255; 
      done;
  c##putImageData (imageData, 0., 0.);
;;


let f select_devices devs data imageData c = 
     compute 0 devs data imageData c;
;;
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val color : int -&gt; int * int * int = &lt;fun&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val compute :
#   int -&gt;
#   Spoc.Devices.device array -&gt;
#   Dom_html.canvasPixelArray Js.t -&gt;
#   'ab62335d6 -&gt;
#   &lt; putImageData : 'ab62335d60 -&gt;
#                    'ad67bff3e -&gt; 'a377bb34a -&gt; 'ab34a1de6 Js.meth;
#     .. &gt;
#   Js.t -&gt; 'ab34a1de6 = &lt;fun&gt;
# </pre>
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val f :
#   'a -&gt;
#   Spoc.Devices.device array -&gt;
#   Dom_html.canvasPixelArray Js.t -&gt;
#   'b -&gt; &lt; putImageData : 'c -&gt; 'd -&gt; 'e -&gt; 'f Js.meth; .. &gt; Js.t -&gt; 'f =
#   &lt;fun&gt;
# </pre>

# %%
open Spoc

let error f = Printf.ksprintf (fun s -> Firebug.console##error (Js.string s); failwith s) f

let go _ =
ignore (
 let canvas =   Js.Opt.get
      (Js.Opt.bind ( Dom_html.document##getElementById("canvas") )
         Dom_html.CoerceTo.canvas)
      (fun () -> error "can't find canvas element canva") in

  let c = canvas##getContext (Dom_html._2d_) in
  
  let devs =
    Devices.init ~only:Devices.OpenCL () in      
          ignore(Kirc.gen ~only:Devices.OpenCL
        mandelbrot);

 let imageData = c##getImageData (0., 0., (float !width), (float !height)) in
 let data = imageData##data in

f 0 devs data imageData c;

  Js._true)


(*let _ = 
  window##onload <- handler go
*)
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">val go : 'a -&gt; unit = &lt;fun&gt;
# </pre>

# %%
go ()
# Out:
# <pre style="color:slategray;max-height:100px;overflow:hidden"
# onclick="
# if (this.style.maxHeight === 'none')
#     this.style.maxHeight = '100px';
# else
#     this.style.maxHeight = 'none';
# ">- : unit = ()
# </pre>

# %% [markdown]
# This cell embedded that canvas element to which we render
#
# <canvas id="canvas" height="512" width="512"></canvas>
